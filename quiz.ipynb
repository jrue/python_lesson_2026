# %% [markdown]
# # Quiz
#
# Follow the instructions below before each cell.

# %%
# Run this cell to load in necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# supress scientific notation (exponents)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
plt.rcParams["axes.formatter.limits"] = (-5, 12)

# %% [markdown]
# ### Load in the CSV file used for this homework quiz
#
# This data is the 2026 NBA player salaries, along with their age, position, and their Player Efficiency Rating (PER) stat, which is a number that takes into account many other stats to determine a players contributions to their team.
#
# Run the cell below to load in this dataset.

# %%
df = pd.read_csv("nba_2026_salary_player_details.csv")

# %% [markdown]
# Let's take a peek and see what the top rows show us:

# %%
df.head()

# %% [markdown]
# ## How many columns and rows in this dataset?

# %% [markdown]
# ### Show the highest paid 10 players in the NBA this year.
#
# hint: Sort values by salary column.

# %% [markdown]
# ### Show the top 10 players with the highest Player Efficiency Rating (PER) stat

# %% [markdown]
# ### Let's see which positions are most represented in this dataset by counting them

# %% [markdown]
# ### Use the "groupby" method to find out which team pays the most by median salary

# %% [markdown]
# ### Use the "groupby" method to find out which team has the highest average (mean) salary?

# %% [markdown]
# ### Use the "groupby" method to find out which position receives the most total (sum) dollars in all of the NBA?

# %% [markdown]
# ### Using filtering, show only the "Golden State Warriors"

# %% [markdown]
# ### Show me players with more than \\$50 million salary

# %% [markdown]
# ### Show me players with a salary between \\$1 million and \\$1.5 million

# %% [markdown]
# ### Make a horizontal bar chart of median salaries by team (groupby) Sort the values.
